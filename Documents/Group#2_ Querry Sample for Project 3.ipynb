-- %% [markdown]
-- ----------------------------------------------------------

-- %% [markdown]
-- 1) Total enrollment per Dept

-- %%
SELECT 
    d.DepartmentName,
    SUM(cl.Enrollment) AS TotalEnrollment
FROM Data.Department d
JOIN Data.Course co
    ON d.DepartmentKey = co.DepartmentKey
JOIN Data.Class cl
    ON co.CourseKey = cl.CourseKey
GROUP BY d.DepartmentName
ORDER BY TotalEnrollment DESC;
-- Out:
-- (3 rows affected)
-- Total execution time: 00:00:00.006
-- <table><tr><th>DepartmentName</th><th>TotalEnrollment</th></tr><tr><td>Computer Science</td><td>50</td></tr><tr><td>Mathematics</td><td>35</td></tr><tr><td>English</td><td>18</td></tr></table>

-- %% [markdown]
-- 2\. Depts and number of courses offered

-- %%
SELECT 
    d.DepartmentCode,
    d.DepartmentName,
    COUNT(c.CourseKey) AS TotalCourses
FROM Data.Department d
LEFT JOIN Data.Course c
    ON d.DepartmentKey = c.DepartmentKey
GROUP BY d.DepartmentCode, d.DepartmentName
ORDER BY TotalCourses DESC;
-- Out:
-- (3 rows affected)
-- Total execution time: 00:00:00.013
-- <table><tr><th>DepartmentCode</th><th>DepartmentName</th><th>TotalCourses</th></tr><tr><td>CSCI</td><td>Computer Science</td><td>2</td></tr><tr><td>MATH</td><td>Mathematics</td><td>1</td></tr><tr><td>ENG</td><td>English</td><td>1</td></tr></table>

-- %% [markdown]
-- 3. Instr w/ their associated Depts

-- %%
SELECT 
    i.InstructorFullName,
    d.DepartmentName
FROM Data.Instructor i
JOIN Data.InstructorDepartment id
    ON i.InstructorKey = id.InstructorKey
JOIN Data.Department d
    ON id.DepartmentKey = d.DepartmentKey
ORDER BY i.InstructorFullName;
-- Out:
-- (3 rows affected)
-- Total execution time: 00:00:00.022
-- <table><tr><th>InstructorFullName</th><th>DepartmentName</th></tr><tr><td>Doe, Alex</td><td>Computer Science</td></tr><tr><td>Morgan, Casey</td><td>English</td></tr><tr><td>Taylor, Jordan</td><td>Mathematics</td></tr></table>

-- %% [markdown]
-- 4\. Classes w/ course title,instructor & lecture mode

-- %%
SELECT 
    c.ClassKey,
    cr.CourseTitle,
    i.InstructorFullName,
    m.ModeName
FROM Data.Class c
JOIN Data.Course cr
    ON c.CourseKey = cr.CourseKey
JOIN Data.Instructor i
    ON c.InstructorKey = i.InstructorKey
JOIN Data.ModeOfInstruction m
    ON c.ModeOfInstructionKey = m.ModeOfInstructionKey
ORDER BY cr.CourseTitle;
-- Out:
-- (4 rows affected)
-- Total execution time: 00:00:00.030
-- <table><tr><th>ClassKey</th><th>CourseTitle</th><th>InstructorFullName</th><th>ModeName</th></tr><tr><td>4</td><td>College Writing</td><td>Morgan, Casey</td><td>In Person</td></tr><tr><td>2</td><td>Data Structures</td><td>Taylor, Jordan</td><td>Hybrid</td></tr><tr><td>3</td><td>Linear Algebra</td><td>Taylor, Jordan</td><td>Online</td></tr><tr><td>1</td><td>Programming Languages</td><td>Doe, Alex</td><td>In Person</td></tr></table>

-- %% [markdown]
-- 5\. Classes that are almost full

-- %%
SELECT 
    ClassKey,
    Enrollment,
    Capacity,
    CAST(Enrollment * 100.0 / Capacity AS DECIMAL(5,2)) AS FillPercentage
FROM Data.Class
WHERE Capacity > 0
  AND Enrollment * 1.0 / Capacity >= 0.80;
-- Out:
-- (2 rows affected)
-- Total execution time: 00:00:00.020
-- <table><tr><th>ClassKey</th><th>Enrollment</th><th>Capacity</th><th>FillPercentage</th></tr><tr><td>1</td><td>28</td><td>35</td><td>80.00</td></tr><tr><td>3</td><td>35</td><td>40</td><td>87.50</td></tr></table>

-- %% [markdown]
-- 6\. Class schedule w/ building and room location

-- %%
SELECT 
    cr.CourseCode,
    c.Section,
    b.BuildingName,
    r.RoomNumber,
    c.Days,
    c.ClassTime
FROM Data.Class c
JOIN Data.Course cr
    ON c.CourseKey = cr.CourseKey
JOIN Location.RoomLocation r
    ON c.RoomLocationKey = r.RoomLocationKey
JOIN Location.BuildingLocation b
    ON r.BuildingLocationKey = b.BuildingLocationKey
ORDER BY b.BuildingName, r.RoomNumber;
-- Out:
-- (4 rows affected)
-- Total execution time: 00:00:00.023
-- <table><tr><th>CourseCode</th><th>Section</th><th>BuildingName</th><th>RoomNumber</th><th>Days</th><th>ClassTime</th></tr><tr><td>ENG 110</td><td>D</td><td>Humanities Hall</td><td>HH-220</td><td>TR</td><td>14:30-15:45</td></tr><tr><td>MATH 241</td><td>C</td><td>Math Hall</td><td>MH-110</td><td>MWF</td><td>13:00-13:50</td></tr><tr><td>CSCI 316</td><td>A</td><td>Science Hall</td><td>SH-201</td><td>MW</td><td>09:15-10:30</td></tr><tr><td>CSCI 320</td><td>B</td><td>Science Hall</td><td>SH-305</td><td>TR</td><td>11:00-12:15</td></tr></table>

-- %% [markdown]
-- 7. Depts offering courses w/ more than 3 credits

-- %%
SELECT DISTINCT
    d.DepartmentName
FROM Data.Department d
JOIN Data.Course c
    ON d.DepartmentKey = c.DepartmentKey
WHERE c.CreditHours > 3;
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.017
-- <table><tr><th>DepartmentName</th></tr><tr><td>Mathematics</td></tr></table>

-- %% [markdown]
-- 8\. Total enrollment per Dept

-- %%
SELECT 
    d.DepartmentName,
    SUM(cl.Enrollment) AS TotalEnrollment
FROM Data.Department d
JOIN Data.Course co
    ON d.DepartmentKey = co.DepartmentKey
JOIN Data.Class cl
    ON co.CourseKey = cl.CourseKey
GROUP BY d.DepartmentName
ORDER BY TotalEnrollment DESC;
-- Out:
-- (3 rows affected)
-- Total execution time: 00:00:00.005
-- <table><tr><th>DepartmentName</th><th>TotalEnrollment</th></tr><tr><td>Computer Science</td><td>50</td></tr><tr><td>Mathematics</td><td>35</td></tr><tr><td>English</td><td>18</td></tr></table>

-- %% [markdown]
-- 10\. User Authorization Trace of Depts

-- %%
SELECT 
    d.DepartmentName,
    ua.GroupMemberFirstName,
    ua.GroupMemberLastName,
    d.DateAdded
FROM Data.Department d
JOIN DbSecurity.UserAuthorization ua
    ON d.UserAuthorizationKey = ua.UserAuthorizationKey
ORDER BY d.DateAdded;
-- Out:
-- (3 rows affected)
-- Total execution time: 00:00:00.021
-- <table><tr><th>DepartmentName</th><th>GroupMemberFirstName</th><th>GroupMemberLastName</th><th>DateAdded</th></tr><tr><td>Computer Science</td><td>Eusan</td><td>Mahatab</td><td>2025-12-17 02:29:26.5809288</td></tr><tr><td>Mathematics</td><td>Eusan</td><td>Mahatab</td><td>2025-12-17 02:29:26.5809288</td></tr><tr><td>English</td><td>Eusan</td><td>Mahatab</td><td>2025-12-17 02:29:26.5809288</td></tr></table>
